td>
# </tr>
# <tr>
# <th scope="row"><label for="Sample00">공시회사명</label></th>
# <td>휴먼푸드</td>
# </tr>
# <tr>
# <th scope="row"><label for="Sample00">종목코드</label></th>
# <td> </td>
# </tr>
# <tr>
# <th scope="row"><label for="Sample00">대표자명</label></th>
# <td>김종철
#
# 			</td>
# </tr>
# <tr>
# <th scope="row"><label for="Sample00">법인구분</label></th>
# <td>
#
#
#
#
#
#
#
#
#
# 				기타법인</td>
# </tr>
# <tr>
# <th scope="row"><label for="Sample00">법인등록번호</label></th>
# <td>134511-0075223</td>
# </tr>
# <tr>
# <th scope="row"><label for="Sample00">사업자등록번호</label></th>
# <td>135-81-66291</td>
# </tr>
# <tr>
# <th scope="row"><label for="Sample00">주소</label></th>
# <td>경기도 수원시 권선구 경수대로 93 4층 (대황교동)</td>
# </tr>
# <tr>
# <th scope="row"><label for="Sample00">홈페이지</label></th>
# <td>
# <a href="http://www.humanfood.co.kr" id="homePage" style="color:#2753f2;" target="_new">www.humanfood.co.kr</a>
# </td>
# </tr>
# <tr>
# <th scope="row"><label for="Sample00">IR홈페이지</label></th>
# <td></td>
# </tr>
# <tr>
# <th scope="row"><label for="Sample00">전화번호</label></th>
# <td>031-281-6085</td>
# </tr>
# <tr>
# <th scope="row"><label for="Sample00">팩스번호</label></th>
# <td>031-281-6087</td>
# </tr>
# <tr>
# <th scope="row"><label for="Sample00">업종명</label></th>
# <td>육류 가공식품 도매업</td>
# </tr>
# <tr>
# <th scope="row"><label for="Sample00">설립일</label></th>
# <td>2003-11-17</td>
# </tr>
# <tr>
# <th scope="row"><label for="Sample00">결산월</label></th>
# <td>12월</td>
# </tr>
# </tbody>

# %%
# 데이터프레임 생성

df_raw=pd.DataFrame({
    '회사명':comp_name,
    '대표자명':owner_name,
    '주소':address,
    '홈페이지':home_page,
    '전화번호':phone_num,
    '팩스번호':fax_num,
    '업종':comp_type,
    '설립일':start_date
    })

pork_done_df=df_raw
pork_done_df

# %%
# 육류 가공식품 데이터 저장
pork_done_df.to_csv('../data/육류 가공식품 도매기업.csv')

# %% [markdown]
# #### 2. 수산물 가공식품 크롤링

# %%
# 라이브러리 로드
from selenium import webdriver #Selenium의 웹 드라이버를 사용하기 위한 모듈을 임포트
from selenium.webdriver.common.by import By #Selenium에서 사용하는 By 클래스를 임포트합. 웹 요소를 검색하는데 사용.
from selenium.webdriver.common.keys import Keys #키보드 입력 제어를 위해 Keys 클래스 임포트
from selenium.webdriver.chrome.service import Service #Chrome 드라이버 서비스를 사용하기 위한 모듈 임포트
from selenium.webdriver.chrome.options import Options #Chrome 드라이버 옵션을 설정하기 위한 클래스 임포트
from webdriver_manager.chrome import ChromeDriverManager #Chrome 드라이버를 자동으로 설치 및 관리하는데 사용되는 드라이버 매니저 임포트
from bs4 import BeautifulSoup #Beautiful soup 크롤링을위해
import pandas as pd
import requests #request 사용을 위해
import re #정규표현을  
import time #timesleep을 위해 사용
import numpy as np
import selenium
import pandas as pd

# %%
#브라우저 꺼짐 방지
chrome_options = Options()
chrome_options.add_experimental_option('detach', True)
#불필요한 에러 메서지 없애기
chrome_options.add_experimental_option('excludeSwitches',['enable-logging'])

# %%
service = Service(executable_path = ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# %%
url = "https://dart.fss.or.kr/dsae001/main.do"
driver.get(url)
driver.maximize_window()
driver.implicitly_wait(5)

# %%
# 업종별 탭
upjong_btn=driver.find_element(By.CSS_SELECTOR,'#businessTab > a')
upjong_btn.click()

# 최상위 분류 
type_btn_1=driver.find_element(By.CSS_SELECTOR,'#root4646 > i')

type_btn_1.click()
time.sleep(1)

# 두 번째 상위 분류 
type_btn_2=driver.find_element(By.XPATH,'//*[@id="46"]/i')
type_btn_2.click()
time.sleep(1)

# 세 번째 상위 분류 
type_btn_3=driver.find_element(By.XPATH,'//*[@id="463"]/i')
type_btn_3.click()
time.sleep(1)

# 네 번재 상위 분류 
type_btn_4=driver.find_element(By.XPATH,'//*[@id="4632"]/i')
type_btn_4.click()
time.sleep(1)

# 마지막 분류
type_btn_end=driver.find_element(By.XPATH,'//*[@id="46329_anchor"]')
type_btn_end.click()
time.sleep(1)
time.sleep(3)

# %%
# 빈 리스트 생성
table_list=[]
com_name = []

# %%
page_list=driver.find_elements(By.CSS_SELECTOR,'#listContents > div.psWrap > div.pageSkip > ul > li')
comp_list=driver.find_elements(By.XPATH,'//*[@id="corpTabel"]/tbody/tr')

# %%
for j in range(len(comp_list)):
    driver.find_element(By.XPATH,f'//*[@id="corpTabel"]/tbody/tr[{j+1}]/td[1]/span/a').click()
    time.sleep(1)
    html=driver.page_source
    soup=BeautifulSoup(html,'html.parser')
    time.sleep(1)
    inform_table=soup.select('#corpDetailTabel > tbody')[0]
    table_list.append(inform_table)
    time.sleep(1)
    comp_name=[]
    owner_name=[]
    address=[]
    home_page=[]
    phone_num=[]
    fax_num=[]
    comp_type=[]
    start_date=[]
    data_list=[]
for j in table_list:
    comp_name.append(j.select('tr>td')[2].text.strip())
    owner_name.append(j.select('tr>td')[4].text.split('\n')[0].lstrip())
    address.append(j.select('tr>td')[8].text.strip())
    home_page.append(j.select('tr>td')[9].text.strip())
    phone_num.append(j.select('tr>td')[11].text)
    fax_num.append(j.select('tr>td')[12].text)
    comp_type.append(j.select('tr>td')[13].text)
    start_date.append(pd.to_datetime(j.select('tr>td')[14].text,format='%Y-%m-%d'))
driver.close()

# %%
# 데이터프레임 생성

df_raw=pd.DataFrame({
    '회사명':comp_name,
    '대표자명':owner_name,
    '주소':address,
    '홈페이지':home_page,
    '전화번호':phone_num,
    '팩스번호':fax_num,
    '업종':comp_type,
    '설립일':start_date
    })

sf_df = df_raw
sf_df

# %%
# 육류 가공식품 데이터 저장
sf_df.to_csv('../data/수산물 가공식품 도매기업.csv')

# %% [markdown]
# #### 3. 빵류, 과자류, 당류, 초콜릿 도매업 크롤링

# %%
# 라이브러리 로드
from selenium import webdriver #Selenium의 웹 드라이버를 사용하기 위한 모듈을 임포트
from selenium.webdriver.common.by import By #Selenium에서 사용하는 By 클래스를 임포트합. 웹 요소를 검색하는데 사용.
from selenium.webdriver.common.keys import Keys #키보드 입력 제어를 위해 Keys 클래스 임포트
from selenium.webdriver.chrome.service import Service #Chrome 드라이버 서비스를 사용하기 위한 모듈 임포트
from selenium.webdriver.chrome.options import Options #Chrome 드라이버 옵션을 설정하기 위한 클래스 임포트
from webdriver_manager.chrome import ChromeDriverManager #Chrome 드라이버를 자동으로 설치 및 관리하는데 사용되는 드라이버 매니저 임포트
from bs4 import BeautifulSoup #Beautiful soup 크롤링을위해
import pandas as pd
import requests #request 사용을 위해
import re #정규표현을  
import time #timesleep을 위해 사용
import numpy as np
import selenium
import pandas as pd

# %%
#브라우저 꺼짐 방지
chrome_options = Options()
chrome_options.add_experimental_option('detach', True)
#불필요한 에러 메서지 없애기
chrome_options.add_experimental_option('excludeSwitches',['enable-logging'])

# %%
service = Service(executable_path = ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# %%
url = "https://dart.fss.or.kr/dsae001/main.do"
driver.get(url)
driver.maximize_window()
driver.implicitly_wait(5)

# %%
# 업종별 탭
upjong_btn=driver.find_element(By.CSS_SELECTOR,'#businessTab > a')
upjong_btn.click()

# 최상위 분류 
type_btn_1=driver.find_element(By.CSS_SELECTOR,'#root4646 > i')

type_btn_1.click()
time.sleep(1)

# 두 번째 상위 분류 
type_btn_2=driver.find_element(By.XPATH,'//*[@id="46"]/i')
type_btn_2.click()
time.sleep(1)

# 세 번째 상위 분류 
type_btn_3=driver.find_element(By.XPATH,'//*[@id="463"]/i')
type_btn_3.click()
time.sleep(1)

# 네 번재 상위 분류 
type_btn_4=driver.find_element(By.XPATH,'//*[@id="4632"]/i')
type_btn_4.click()
time.sleep(1)

# 마지막 분류
type_btn_end=driver.find_element(By.XPATH,'//*[@id="46323_anchor"]')
type_btn_end.click()
time.sleep(1)
time.sleep(3)

# %%
# 빈 리스트 생성
table_list=[]
com_name = []

# %%
page_list=driver.find_elements(By.CSS_SELECTOR,'#listContents > div.psWrap > div.pageSkip > ul > li')
comp_list=driver.find_elements(By.XPATH,'//*[@id="corpTabel"]/tbody/tr')

# %%
for j in range(len(comp_list)):
    driver.find_element(By.XPATH,f'//*[@id="corpTabel"]/tbody/tr[{j+1}]/td[1]/span/a').click()
    time.sleep(1)
    html=driver.page_source
    soup=BeautifulSoup(html,'html.parser')
    time.sleep(1)
    inform_table=soup.select('#corpDetailTabel > tbody')[0]
    table_list.append(inform_table)
    time.sleep(1)
    comp_name=[]
    owner_name=[]
    address=[]
    home_page=[]
    phone_num=[]
    fax_num=[]
    comp_type=[]
    start_date=[]
    data_list=[]
for j in table_list:
    comp_name.append(j.select('tr>td')[2].text.strip())
    owner_name.append(j.select('tr>td')[4].text.split('\n')[0].lstrip())
    address.append(j.select('tr>td')[8].text.strip())
    home_page.append(j.select('tr>td')[9].text.strip())
    phone_num.append(j.select('tr>td')[11].text)
    fax_num.append(j.select('tr>td')[12].text)
    comp_type.append(j.select('tr>td')[13].text)
    start_date.append(pd.to_datetime(j.select('tr>td')[14].text,format='%Y-%m-%d'))
driver.close()

# %%
# 데이터프레임 생성

df_raw=pd.DataFrame({
    '회사명':comp_name,
    '대표자명':owner_name,
    '주소':address,
    '홈페이지':home_page,
    '전화번호':phone_num,
    '팩스번호':fax_num,
    '업종':comp_type,
    '설립일':start_date
    })

bread_df = df_raw
bread_df

# %%
# 빵류, 과자류 가공식품 데이터 저장
bread_df.to_csv('../data/빵류, 과자류 도매기업.csv')

# %% [markdown]
# #### 4. 낙농품 및 동식물성 유지 도매업 크롤링

# %%
# 라이브러리 로드
from selenium import webdriver #Selenium의 웹 드라이버를 사용하기 위한 모듈을 임포트
from selenium.webdriver.common.by import By #Selenium에서 사용하는 By 클래스를 임포트합. 웹 요소를 검색하는데 사용.
from selenium.webdriver.common.keys import Keys #키보드 입력 제어를 위해 Keys 클래스 임포트
from selenium.webdriver.chrome.service import Service #Chrome 드라이버 서비스를 사용하기 위한 모듈 임포트
from selenium.webdriver.chrome.options import Options #Chrome 드라이버 옵션을 설정하기 위한 클래스 임포트
from webdriver_manager.chrome import ChromeDriverManager #Chrome 드라이버를 자동으로 설치 및 관리하는데 사용되는 드라이버 매니저 임포트
from bs4 import BeautifulSoup #Beautiful soup 크롤링을위해
import pandas as pd
import requests #request 사용을 위해
import re #정규표현을  
import time #timesleep을 위해 사용
import numpy as np
import selenium
import pandas as pd

# %%
#브라우저 꺼짐 방지
chrome_options = Options()
chrome_options.add_experimental_option('detach', True)
#불필요한 에러 메서지 없애기
chrome_options.add_experimental_option('excludeSwitches',['enable-logging'])

# %%
service = Service(executable_path = ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# %%
url = "https://dart.fss.or.kr/dsae001/main.do"
driver.get(url)
driver.maximize_window()
driver.implicitly_wait(5)

# %%
# 업종별 탭
upjong_btn=driver.find_element(By.CSS_SELECTOR,'#businessTab > a')
upjong_btn.click()

# 최상위 분류 
type_btn_1=driver.find_element(By.CSS_SELECTOR,'#root4646 > i')
type_btn_1.click()
time.sleep(1)

# 두 번째 상위 분류 
type_btn_2=driver.find_element(By.XPATH,'//*[@id="46"]/i')
type_btn_2.click()
time.sleep(1)

# 세 번째 상위 분류 
type_btn_3=driver.find_element(By.XPATH,'//*[@id="463"]/i')
type_btn_3.click()
time.sleep(1)

# 네 번재 상위 분류 
type_btn_4=driver.find_element(By.XPATH,'//*[@id="4632"]/i')
type_btn_4.click()
time.sleep(1)

# 마지막 분류
type_btn_end=driver.find_element(By.XPATH,'//*[@id="46324_anchor"]')
type_btn_end.click()
time.sleep(1)
time.sleep(3)

# %%
# 빈 리스트 생성
table_list=[]
com_name = []

# %%
page_list=driver.find_elements(By.CSS_SELECTOR,'#listContents > div.psWrap > div.pageSkip > ul > li')
comp_list=driver.find_elements(By.XPATH,'//*[@id="corpTabel"]/tbody/tr')

# %%
for j in range(len(comp_list)):
    driver.find_element(By.XPATH,f'//*[@id="corpTabel"]/tbody/tr[{j+1}]/td[1]/span/a').click()
    time.sleep(1)
    html=driver.page_source
    soup=BeautifulSoup(html,'html.parser')
    time.sleep(1)
    inform_table=soup.select('#corpDetailTabel > tbody')[0]
    table_list.append(inform_table)
    time.sleep(1)
    comp_name=[]
    owner_name=[]
    address=[]
    home_page=[]
    phone_num=[]
    fax_num=[]
    comp_type=[]
    start_date=[]
    data_list=[]
for j in table_list:
    comp_name.append(j.select('tr>td')[2].text.strip())
    owner_name.append(j.select('tr>td')[4].text.split('\n')[0].lstrip())
    address.append(j.select('tr>td')[8].text.strip())
    home_page.append(j.select('tr>td')[9].text.strip())
    phone_num.append(j.select('tr>td')[11].text)
    fax_num.append(j.select('tr>td')[12].text)
    comp_type.append(j.select('tr>td')[13].text)
    start_date.append(pd.to_datetime(j.select('tr>td')[14].text,format='%Y-%m-%d'))
driver.close()

# %%
# 데이터프레임 생성

df_raw=pd.DataFrame({
    '회사명':comp_name,
    '대표자명':owner_name,
    '주소':address,
    '홈페이지':home_page,
    '전화번호':phone_num,
    '팩스번호':fax_num,
    '업종':comp_type,
    '설립일':start_date
    })

milk_df = df_raw
milk_df

# %%
# 낙농품 및 동식물성 유지 도매업 데이터 저장
milk_df.to_csv('../data/낙농품 및 동식물성 유지 도매기업.csv')

# %% [markdown]
# #### 5. 커피 및 차류 도매업 크롤링

# %%
# 라이브러리 로드
from selenium import webdriver #Selenium의 웹 드라이버를 사용하기 위한 모듈을 임포트
from selenium.webdriver.common.by import By #Selenium에서 사용하는 By 클래스를 임포트합. 웹 요소를 검색하는데 사용.
from selenium.webdriver.common.keys import Keys #키보드 입력 제어를 위해 Keys 클래스 임포트
from selenium.webdriver.chrome.service import Service #Chrome 드라이버 서비스를 사용하기 위한 모듈 임포트
from selenium.webdriver.chrome.options import Options #Chrome 드라이버 옵션을 설정하기 위한 클래스 임포트
from webdriver_manager.chrome import ChromeDriverManager #Chrome 드라이버를 자동으로 설치 및 관리하는데 사용되는 드라이버 매니저 임포트
from bs4 import BeautifulSoup #Beautiful soup 크롤링을위해
import pandas as pd
import requests #request 사용을 위해
import re #정규표현을  
import time #timesleep을 위해 사용
import numpy as np
import selenium
import pandas as pd

# %%
#브라우저 꺼짐 방지
chrome_options = Options()
chrome_options.add_experimental_option('detach', True)
#불필요한 에러 메서지 없애기
chrome_options.add_experimental_option('excludeSwitches',['enable-logging'])

# %%
service = Service(executable_path = ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# %%
url = "https://dart.fss.or.kr/dsae001/main.do"
driver.get(url)
driver.maximize_window()
driver.implicitly_wait(5)

# %%
# 업종별 탭
upjong_btn=driver.find_element(By.CSS_SELECTOR,'#businessTab > a')
upjong_btn.click()

# 최상위 분류 
type_btn_1=driver.find_element(By.CSS_SELECTOR,'#root4646 > i')
type_btn_1.click()
time.sleep(1)

# 두 번째 상위 분류 
type_btn_2=driver.find_element(By.XPATH,'//*[@id="46"]/i')
type_btn_2.click()
time.sleep(1)

# 세 번째 상위 분류 
type_btn_3=driver.find_element(By.XPATH,'//*[@id="463"]/i')
type_btn_3.click()
time.sleep(1)

# 네 번재 상위 분류 
type_btn_4=driver.find_element(By.XPATH,'//*[@id="4632"]/i')
type_btn_4.click()
time.sleep(1)

# 마지막 분류
type_btn_end=driver.find_element(By.XPATH,'//*[@id="46325_anchor"]')
type_btn_end.click()
time.sleep(1)
time.sleep(3)

# %%
# 빈 리스트 생성
table_list=[]
com_name = []

# %%
page_list=driver.find_elements(By.CSS_SELECTOR,'#listContents > div.psWrap > div.pageSkip > ul > li')
comp_list=driver.find_elements(By.XPATH,'//*[@id="corpTabel"]/tbody/tr')

# %%
for j in range(len(comp_list)):
    driver.find_element(By.XPATH,f'//*[@id="corpTabel"]/tbody/tr[{j+1}]/td[1]/span/a').click()
    time.sleep(1)
    html=driver.page_source
    soup=BeautifulSoup(html,'html.parser')
    time.sleep(1)
    inform_table=soup.select('#corpDetailTabel > tbody')[0]
    table_list.append(inform_table)
    time.sleep(1)
    comp_name=[]
    owner_name=[]
    address=[]
    home_page=[]
    phone_num=[]
    fax_num=[]
    comp_type=[]
    start_date=[]
    data_list=[]
for j in table_list:
    comp_name.append(j.select('tr>td')[2].text.strip())
    owner_name.append(j.select('tr>td')[4].text.split('\n')[0].lstrip())
    address.append(j.select('tr>td')[8].text.strip())
    home_page.append(j.select('tr>td')[9].text.strip())
    phone_num.append(j.select('tr>td')[11].text)
    fax_num.append(j.select('tr>td')[12].text)
    comp_type.append(j.select('tr>td')[13].text)
    start_date.append(pd.to_datetime(j.select('tr>td')[14].text,format='%Y-%m-%d'))
driver.close()

# %%
# 데이터프레임 생성

df_raw=pd.DataFrame({
    '회사명':comp_name,
    '대표자명':owner_name,
    '주소':address,
    '홈페이지':home_page,
    '전화번호':phone_num,
    '팩스번호':fax_num,
    '업종':comp_type,
    '설립일':start_date
    })

coffee_df = df_raw
coffee_df

# %%
# 낙농품 및 동식물성 유지 도매업 데이터 저장
coffee_df.to_csv('../data/낙농품 및 동식물성 유지 도매기업.csv')

# %% [markdown]
# #### 6. 조미료 도매업 크롤링

# %%
# 라이브러리 로드
from selenium import webdriver #Selenium의 웹 드라이버를 사용하기 위한 모듈을 임포트
from selenium.webdriver.common.by import By #Selenium에서 사용하는 By 클래스를 임포트합. 웹 요소를 검색하는데 사용.
from selenium.webdriver.common.keys import Keys #키보드 입력 제어를 위해 Keys 클래스 임포트
from selenium.webdriver.chrome.service import Service #Chrome 드라이버 서비스를 사용하기 위한 모듈 임포트
from selenium.webdriver.chrome.options import Options #Chrome 드라이버 옵션을 설정하기 위한 클래스 임포트
from webdriver_manager.chrome import ChromeDriverManager #Chrome 드라이버를 자동으로 설치 및 관리하는데 사용되는 드라이버 매니저 임포트
from bs4 import BeautifulSoup #Beautiful soup 크롤링을위해
import pandas as pd
import requests #request 사용을 위해
import re #정규표현을  
import time #timesleep을 위해 사용
import numpy as np
import selenium
import pandas as pd

# %%
#브라우저 꺼짐 방지
chrome_options = Options()
chrome_options.add_experimental_option('detach', True)
#불필요한 에러 메서지 없애기
chrome_options.add_experimental_option('excludeSwitches',['enable-logging'])

# %%
service = Service(executable_path = ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# %%
url = "https://dart.fss.or.kr/dsae001/main.do"
driver.get(url)
driver.maximize_window()
driver.implicitly_wait(5)

# %%
# 업종별 탭
upjong_btn=driver.find_element(By.CSS_SELECTOR,'#businessTab > a')
upjong_btn.click()

# 최상위 분류 
type_btn_1=driver.find_element(By.CSS_SELECTOR,'#root4646 > i')
type_btn_1.click()
time.sleep(1)

# 두 번째 상위 분류 
type_btn_2=driver.find_element(By.XPATH,'//*[@id="46"]/i')
type_btn_2.click()
time.sleep(1)

# 세 번째 상위 분류 
type_btn_3=driver.find_element(By.XPATH,'//*[@id="463"]/i')
type_btn_3.click()
time.sleep(1)

# 네 번재 상위 분류 
type_btn_4=driver.find_element(By.XPATH,'//*[@id="4632"]/i')
type_btn_4.click()
time.sleep(1)

# 마지막 분류
type_btn_end=driver.find_element(By.XPATH,'//*[@id="46326_anchor"]')
type_btn_end.click()
time.sleep(1)
time.sleep(3)

# %%
# 빈 리스트 생성
table_list=[]
com_name = []

# %%
page_list=driver.find_elements(By.CSS_SELECTOR,'#listContents > div.psWrap > div.pageSkip > ul > li')
comp_list=driver.find_elements(By.XPATH,'//*[@id="corpTabel"]/tbody/tr')

# %%
for j in range(len(comp_list)):
    driver.find_element(By.XPATH,f'//*[@id="corpTabel"]/tbody/tr[{j+1}]/td[1]/span/a').click()
    time.sleep(1)
    html=driver.page_source
    soup=BeautifulSoup(html,'html.parser')
    time.sleep(1)
    inform_table=soup.select('#corpDetailTabel > tbody')[0]
    table_list.append(inform_table)
    time.sleep(1)
    comp_name=[]
    owner_name=[]
    address=[]
    home_page=[]
    phone_num=[]
    fax_num=[]
    comp_type=[]
    start_date=[]
    data_list=[]
for j in table_list:
    comp_name.append(j.select('tr>td')[2].text.strip())
    owner_name.append(j.select('tr>td')[4].text.split('\n')[0].lstrip())
    address.append(j.select('tr>td')[8].text.strip())
    home_page.append(j.select('tr>td')[9].text.strip())
    phone_num.append(j.select('tr>td')[11].text)
    fax_num.append(j.select('tr>td')[12].text)
    comp_type.append(j.select('tr>td')[13].text)
    start_date.append(pd.to_datetime(j.select('tr>td')[14].text,format='%Y-%m-%d'))
driver.close()

# %%
# 데이터프레임 생성

df_raw=pd.DataFrame({
    '회사명':comp_name,
    '대표자명':owner_name,
    '주소':address,
    '홈페이지':home_page,
    '전화번호':phone_num,
    '팩스번호':fax_num,
    '업종':comp_type,
    '설립일':start_date
    })

con_df = df_raw
con_df

# %%
# 조미료 도매업 데이터 저장
con_df.to_csv('../data/조미료 도매기업.csv')

# %% [markdown]
# #### 7. 기타 가공식품 도매업 크롤링

# %%
# 라이브러리 로드
from selenium import webdriver #Selenium의 웹 드라이버를 사용하기 위한 모듈을 임포트
from selenium.webdriver.common.by import By #Selenium에서 사용하는 By 클래스를 임포트합. 웹 요소를 검색하는데 사용.
from selenium.webdriver.common.keys import Keys #키보드 입력 제어를 위해 Keys 클래스 임포트
from selenium.webdriver.chrome.service import Service #Chrome 드라이버 서비스를 사용하기 위한 모듈 임포트
from selenium.webdriver.chrome.options import Options #Chrome 드라이버 옵션을 설정하기 위한 클래스 임포트
from webdriver_manager.chrome import ChromeDriverManager #Chrome 드라이버를 자동으로 설치 및 관리하는데 사용되는 드라이버 매니저 임포트
from bs4 import BeautifulSoup #Beautiful soup 크롤링을위해
import pandas as pd
import requests #request 사용을 위해
import re #정규표현을  
import time #timesleep을 위해 사용
import numpy as np
import selenium
import pandas as pd

# %%
#브라우저 꺼짐 방지
chrome_options = Options()
chrome_options.add_experimental_option('detach', True)
#불필요한 에러 메서지 없애기
chrome_options.add_experimental_option('excludeSwitches',['enable-logging'])

# %%
service = Service(executable_path = ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# %%
url = "https://dart.fss.or.kr/dsae001/main.do"
driver.get(url)
driver.maximize_window()
driver.implicitly_wait(5)

# %%
# 업종별 탭
upjong_btn=driver.find_element(By.CSS_SELECTOR,'#businessTab > a')
upjong_btn.click()

# 최상위 분류 
type_btn_1=driver.find_element(By.CSS_SELECTOR,'#root4646 > i')
type_btn_1.click()
time.sleep(1)

# 두 번째 상위 분류 
type_btn_2=driver.find_element(By.XPATH,'//*[@id="46"]/i')
type_btn_2.click()
time.sleep(1)

# 세 번째 상위 분류 
type_btn_3=driver.find_element(By.XPATH,'//*[@id="463"]/i')
type_btn_3.click()
time.sleep(1)

# 네 번재 상위 분류 
type_btn_4=driver.find_element(By.XPATH,'//*[@id="4632"]/i')
type_btn_4.click()
time.sleep(1)

# 마지막 분류
type_btn_end=driver.find_element(By.XPATH,'//*[@id="46329_anchor"]')
type_btn_end.click()
time.sleep(1)
time.sleep(3)

# %%
# 빈 리스트 생성
table_list=[]
com_name = []
table1_list=[]

# %%
page_list=driver.find_elements(By.CSS_SELECTOR,'#listContents > div.psWrap > div.pageSkip > ul > li')
comp_list=driver.find_elements(By.XPATH,'//*[@id="corpTabel"]/tbody/tr')

# %%
# 1페이지 크롤링
for j in range(len(comp_list)):
    driver.find_element(By.XPATH,f'//*[@id="corpTabel"]/tbody/tr[{j+1}]/td[1]/span/a').click()
    time.sleep(1)
    html=driver.page_source
    soup=BeautifulSoup(html,'html.parser')
    time.sleep(1)
    inform_table=soup.select('#corpDetailTabel > tbody')[0]
    table_list.append(inform_table)
    time.sleep(1)

# %%
# 2페이지 크롤링
for j in range(len(comp_list)):
    driver.find_element(By.XPATH,f'//*[@id="corpTabel"]/tbody/tr[{j+1}]/td[1]/span/a').click()
    time.sleep(1)
    html=driver.page_source
    soup=BeautifulSoup(html,'html.parser')
    time.sleep(1)
    inform_table=soup.select('#corpDetailTabel > tbody')[0]
    table1_list.append(inform_table)
    time.sleep(1)

# %%
# 빈 리스트 생성
comp_name=[]
owner_name=[]
address=[]
home_page=[]
phone_num=[]
fax_num=[]
comp_type=[]
start_date=[]
ata_list=[]

# %%
# 1페이지 데이터프레임 생성
for j in table_list:
    comp_name.append(j.select('tr>td')[2].text.strip())
    owner_name.append(j.select('tr>td')[4].text.split('\n')[0].lstrip())
    address.append(j.select('tr>td')[8].text.strip())
    home_page.append(j.select('tr>td')[9].text.strip())
    phone_num.append(j.select('tr>td')[11].text)
    fax_num.append(j.select('tr>td')[12].text)
    comp_type.append(j.select('tr>td')[13].text)
    start_date.append(pd.to_datetime(j.select('tr>td')[14].text,format='%Y-%m-%d'))

# %%
# 1페이지 데이터프레임 생성
for j in table1_list:
    comp_name.append(j.select('tr>td')[2].text.strip())
    owner_name.append(j.select('tr>td')[4].text.split('\n')[0].lstrip())
    address.append(j.select('tr>td')[8].text.strip())
    home_page.append(j.select('tr>td')[9].text.strip())
    phone_num.append(j.select('tr>td')[11].text)
    fax_num.append(j.select('tr>td')[12].text)
    comp_type.append(j.select('tr>td')[13].text)
    start_date.append(pd.to_datetime(j.select('tr>td')[14].text,format='%Y-%m-%d'))

# %%
df_raw=pd.DataFrame({
    '회사명':comp_name,
    '대표자명':owner_name,
    '주소':address,
    '홈페이지':home_page,
    '전화번호':phone_num,
    '팩스번호':fax_num,
    '업종':comp_type,
    '설립일':start_date
    })

etc_df=df_raw
etc_df

# %%
df_raw=pd.DataFrame({
    '회사명':comp_name,
    '대표자명':owner_name,
    '주소':address,
    '홈페이지':home_page,
    '전화번호':phone_num,
    '팩스번호':fax_num,
    '업종':comp_type,
    '설립일':start_date
    })

etc_df1=df_raw
etc_df1

# %%
# 1페이지, 2페이지 concat으로 데이터 병합
df = pd.concat([etc_df, etc_df1])
df.reset_index(inplace=True)
df = df.drop_duplicates()
del df['index']
df

# %%
df.to_csv('../data/기타 도매기업.csv')
